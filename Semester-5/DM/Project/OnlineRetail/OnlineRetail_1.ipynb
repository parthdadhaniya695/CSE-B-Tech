# %%
import pandas as pd

# %%
# reding file
olr=pd.read_csv('OnlineRetail.csv',encoding='ISO-8859-1')

# %%
# printing file
olr
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#1 first 10 row
olr.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
#2 sow last 10
olr.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541899  12/9/2011 12:50       3.75     12680.0  France
# 541900  12/9/2011 12:50       3.75     12680.0  France
# ...

# %%
# 3 datatype of each collem
olr.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
# 4 samary informetion
olr.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# 5 Access by column name -get the data from one column
olr['Description']
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
# 6  dimensions 
olr.shape
# Out:
# (541909, 8)

# %%
# 7 Access rows by their integer location
olr.iloc[0]
# Out:
# InvoiceNo                                  536365
# StockCode                                  85123A
# Description    WHITE HANGING HEART T-LIGHT HOLDER
# Quantity                                        6
# InvoiceDate                        12/1/2010 8:26
# UnitPrice                                    2.55
# CustomerID                                17850.0
# Country                            United Kingdom
# Name: 0, dtype: object

# %%
# 8 copy and deleat the collem
olr_copy = olr.copy()
olr_copy.drop('Description', axis=1, inplace=True)
olr_copy
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   12/1/2010 8:26       2.55     17850.0
# 1         536365     71053         6   12/1/2010 8:26       3.39     17850.0
# 2         536365    84406B         8   12/1/2010 8:26       2.75     17850.0
# 3         536365    84029G         6   12/1/2010 8:26       3.39     17850.0
# 4         536365    84029E         6   12/1/2010 8:26       3.39     17850.0
# ...          ...       ...       ...              ...        ...         ...
# 541904    581587     22613        12  12/9/2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12/9/2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12/9/2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12/9/2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12/9/2011 12:50       4.95     12680.0
#
#                Country
# ...

# %%
# 9 Create a new Column
olr['DoubleQuantity'] = olr['Quantity'] * 2

# %%
olr
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  DoubleQuantity
# ...

# %%
# 10 Perform Condition Selection on DataFrame
olr['Quantity']
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 541909, dtype: int64

# %%
# 11 mean of UnitPrice
olr['UnitPrice'].mean()
# Out:
# np.float64(4.611113626088513)

# %%
# 12 max
olr['UnitPrice'].max()
# Out:
# 38970.0

# %%
# 13 sum
olr['UnitPrice'].sum()
# Out:
# np.float64(2498803.974)

# %%
#14 min
olr['UnitPrice'].min()
# Out:
# -11062.06

# %%
# 15 Grouping and Aggregatio
olr_copy.groupby('Country').count()
# Out:
#                       InvoiceNo  StockCode  Quantity  InvoiceDate  UnitPrice  \
# Country
# Australia                  1259       1259      1259         1259       1259
# Austria                     401        401       401          401        401
# Bahrain                      19         19        19           19         19
# Belgium                    2069       2069      2069         2069       2069
# Brazil                       32         32        32           32         32
# Canada                      151        151       151          151        151
# Channel Islands             758        758       758          758        758
# Cyprus                      622        622       622          622        622
# Czech Republic               30         30        30           30         30
# Denmark                     389        389       389          389        389
# EIRE                       8196       8196      8196         8196       8196
# ...

# %%
olr_copy
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   12/1/2010 8:26       2.55     17850.0
# 1         536365     71053         6   12/1/2010 8:26       3.39     17850.0
# 2         536365    84406B         8   12/1/2010 8:26       2.75     17850.0
# 3         536365    84029G         6   12/1/2010 8:26       3.39     17850.0
# 4         536365    84029E         6   12/1/2010 8:26       3.39     17850.0
# ...          ...       ...       ...              ...        ...         ...
# 541904    581587     22613        12  12/9/2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12/9/2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12/9/2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12/9/2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12/9/2011 12:50       4.95     12680.0
#
#                Country
# ...

# %%
# 16  Pivot Tables
pd.pivot_table(olr_copy,index='Country',values='Quantity',aggfunc='sum')
# Out:
#                       Quantity
# Country
# Australia                83653
# Austria                   4827
# Bahrain                    260
# Belgium                  23152
# Brazil                     356
# Canada                    2763
# Channel Islands           9479
# Cyprus                    6317
# Czech Republic             592
# Denmark                   8188
# EIRE                    142637
# European Community         497
# Finland                  10666
# France                  110480
# Germany                 117448
# Greece                    1556
# Hong Kong                 4769
# Iceland                   2458
# Israel                    4353
# Italy                     7999
# Japan                    25218
# Lebanon                    386
# Lithuania                  652
# Malta                      944
# Netherlands             200128
# Norway                   19247
# Poland                    3653
# Portugal                 16180
# RSA                        352
# ...

# %%
#17 date time
olr_copy['Date']=pd.to_datetime(olr_copy['InvoiceDate'])
olr_copy['year']=olr_copy['Date'].dt.year
olr_copy['Month'] = olr_copy['Date'].dt.month
olr_copy[olr_copy['Date'] > '2011-01-01']
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 42481     539993     22386        10   1/4/2011 10:00       1.95     13313.0
# 42482     539993     21499        25   1/4/2011 10:00       0.42     13313.0
# 42483     539993     21498        25   1/4/2011 10:00       0.42     13313.0
# 42484     539993     22379         5   1/4/2011 10:00       2.10     13313.0
# 42485     539993     20718        10   1/4/2011 10:00       1.25     13313.0
# ...          ...       ...       ...              ...        ...         ...
# 541904    581587     22613        12  12/9/2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12/9/2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12/9/2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12/9/2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12/9/2011 12:50       4.95     12680.0
#
# ...

# %%
# 18	Get the index 
olr.index
# Out:
# RangeIndex(start=0, stop=541909, step=1)

# %%
# 19 info
olr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       541909 non-null  object
#  1   StockCode       541909 non-null  object
#  2   Description     540455 non-null  object
#  3   Quantity        541909 non-null  int64
#  4   InvoiceDate     541909 non-null  object
#  5   UnitPrice       541909 non-null  float64
#  6   CustomerID      406829 non-null  float64
#  7   Country         541909 non-null  object
#  8   DoubleQuantity  541909 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
# 20 isnull
olr.isnull().sum()
# Out:
# InvoiceNo              0
# StockCode              0
# Description         1454
# Quantity               0
# InvoiceDate            0
# UnitPrice              0
# CustomerID        135080
# Country                0
# DoubleQuantity         0
# dtype: int64

# %%
# 21 duplicated
olr_copy.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 541909, dtype: bool

# %%
#22 drop_duplicates
olr_copy.drop_duplicates()
olr_copy
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   12/1/2010 8:26       2.55     17850.0
# 1         536365     71053         6   12/1/2010 8:26       3.39     17850.0
# 2         536365    84406B         8   12/1/2010 8:26       2.75     17850.0
# 3         536365    84029G         6   12/1/2010 8:26       3.39     17850.0
# 4         536365    84029E         6   12/1/2010 8:26       3.39     17850.0
# ...          ...       ...       ...              ...        ...         ...
# 541904    581587     22613        12  12/9/2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12/9/2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12/9/2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12/9/2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12/9/2011 12:50       4.95     12680.0
#
# ...
